# %%
import matplotlib.pyplot as plt
import random
import numpy as np

# Demo with Plots!!
# focus on triangle
xb = random.uniform(0,0.5)
yb = random.uniform(0,0.5)
xb, yb = (xb, yb) if xb >= yb else (yb, xb)

xr = random.uniform(0,1)
yr = random.uniform(0,1)

b = (yr**2 - yb**2 + xr**2 - xb**2)/(2 * (yr - yb))
m = - (xr - xb) / (yr - yb)

equix = lambda x: m*x + b
equiy = lambda y: (y-b)/m

fig, ax = plt.subplots()

circle1 = plt.Circle((0,0), np.sqrt(xb**2 + yb**2), fill=False)
circle2 = plt.Circle((1,0), np.sqrt((1-xb)**2 + yb**2), fill=False)
ax.add_patch(circle1)
ax.add_patch(circle2)

# THE BOX
plt.plot([0, 1, 1, 0, 0], [0, 0, 1, 1, 0])

# red point
plt.plot(xr, yr, "r*"), 

# blue point
plt.plot(xb, yb, "b*"), 

# plot line
xrange = np.arange(-0.1, 1.2, 0.1)
plt.plot(xrange, equix(xrange), "k")
plt.ylim([-0.2,1.2])

# edges
# if abs(yb) < xb:
#     print("right")
#     cond = -1 < m + b < 1
# elif abs(yb) < -xb:
#     print("left")
#     cond = -1 < -m + b < 1 
# elif abs(xb) < yb:
#     print("top")
#     cond = -1 < (1-b)/m < 1
# elif abs(xb) < -yb:
#     print("bottom")
#     cond = -1 < (-1-b)/m < 1
# print(cond)

# modified so it should always be on the bottom
cond = 0 < -b/m < 1
print(cond)
def shaded(x, y):
    theta = 2*np.arctan2(y,x)
    return 0.25 * (x**2 + y**2) * (np.pi + np.sin(theta) - theta)
a = lambda x,y: shaded(x,y) + shaded(1-x, y)
a(xb, yb)
# Out:
# False
# 0.7137032754705754

# %%
# From running besidesthepoint.py
successes = 32645598036341
trials = 66432800000000
successes/trials

# looks like this approach isn't going to work though, for 10 decimal precision at 95% confidence I would need to run this for 18,000 years
# Out:
# 0.4914078292099836

# %%
# Can probably squeeze out a bit more efficiency with the array operations (see the below math), but don't think it will be significant
from sympy import pprint, symbols, simplify

# Define the symbols
yr, yb, xr, xb = symbols('yr yb xr xb')

# Define the expressions
b = (yr**2 - yb**2 + xr**2 - xb**2) / (2 * (yr - yb))
m = -(xr - xb) / (yr - yb)

squares = xb**2 - xr**2 + yb**2 - yr**2
dx = 2 * (xb - xr)
dy = 2 * (yb - yr)

# Simplify the expressions
pprint(simplify(b+m))
pprint(simplify(b-m))
pprint(simplify((1-b)/m))
pprint(simplify((-1-b)/m))

squares = xb**2 - xr**2 + yb**2 - yr**2
dx = 2 * (xb - xr)
dy = 2 * (yb - yr)

# in terms of slope and y intercept
a = (b+m, b-m, (1-b)/m, (-1-b)/m)

# in terms of squares and deltas
b = ((squares - dx)/dy, (squares + dx)/dy, (squares - dy)/dx, (squares + dy)/dx)

for i,j in zip(a,b):
    print(simplify(i) == simplify(j))
# Out:
#   2            2            2     2
# xb  - 2⋅xb - xr  + 2⋅xr + yb  - yr
# ───────────────────────────────────
#             2⋅(yb - yr)
#   2            2            2     2
# xb  + 2⋅xb - xr  - 2⋅xr + yb  - yr
# ───────────────────────────────────
#             2⋅(yb - yr)
#   2     2     2            2
# xb  - xr  + yb  - 2⋅yb - yr  + 2⋅yr
# ───────────────────────────────────
#             2⋅(xb - xr)
#   2     2     2            2
# xb  - xr  + yb  + 2⋅yb - yr  - 2⋅yr
# ───────────────────────────────────
#             2⋅(xb - xr)
# True
# True
# True
# True

# %% [markdown]
# Initially I made this expression
#
# $8 \int_0^{\frac{1}{2}} \int_0^{x} \left( \int_0^x  \sqrt{x^2 + y^2 - z^2} \, dz + \int_{x-1}^1 \sqrt{(x-1)^2 + y^2 - (z-1)^2} \, dz \right) \, dy \, dx
# $
#
# But after flipping the circle, it looks a little simpler
#
# $8 \int_0^{\frac{1}{2}} \int_0^x \left( \int_0^x \sqrt{x^2 + y^2 - z^2} \, dz + \int_0^{1 - x} \sqrt{(1 - x)^2 + y^2 - z^2} \, dz \right) dy \, dx
# $

# %%
# New approach - solving this integral should give us an exact answer. Tried this - doesn't work
from sympy import integrate, sqrt, N

x, y, z = symbols('x y z')

integrand1 = sqrt(x**2 + y**2 - z**2)
integrand2 = sqrt((1-x)**2 + y**2 - z**2)

# neither of these work

# 8 * integrate(integrate(integrate(integrand1, (z, 0, x)) + integrate(integrand2, (z, 0, 1-x)), (y, 0, x)), (x, 0, 1/2))

# N(8 * integrate(integrate(integrate(integrand1, (z, 0, x)) + integrate(integrand2, (z, 0, 1-x)), (y, 0, x)), (x, 0, 1/2)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 12
#       7 integrand2 = sqrt((1-x)**2 + y**2 - z**2)
#       9 # Integral
#      10 # 8 * integrate(integrate(integrate(integrand1, (z, 0, x)) + integrate(integrand2, (z, 0, 1-x)), (y, 0, x)), (x, 0, 1/2))
# ---> 12 N(8 * integrate(integrate(integrate(integrand1, (z, 0, x)) + integrate(integrand2, (z, 0, 1-x)), (y, 0, x)), (x, 0, 1/2)))
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/integrals/integrals.py:1574, in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1571 integral = Integral(*args, **kwargs)
#    1573 if isinstance(integral, Integral):
# -> 1574     return integral.doit(**doit_flags)
#    1575 else:
#    1576     new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#    1577         for a in integral.args]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/integrals/integrals.py:506, in Integral.doit(self, **hints)
#     504 if reps:
#     505     undo = {v: k for k, v in reps.items()}
# --> 506     did = self.xreplace(reps).doit(**hints)
#     507     if isinstance(did, tuple):  # when separate=True
#     508         did = tuple([i.xreplace(undo) for i in did])
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/integrals/integrals.py:557, in Integral.doit(self, **hints)
#     554         antideriv = function._eval_integral(xab[0],
#     555             **eval_kwargs)
#     556     else:
# --> 557         antideriv = self._eval_integral(
#     558             function, xab[0], **eval_kwargs)
#     559 else:
#     560     # There are a number of tradeoffs in using the
#     561     # Meijer G method. It can sometimes be a lot faster
#    (...)
#     566     # integration methods to try, in what order. See the
#     567     # integrate() docstring for details.
#     568     def try_meijerg(function, xab):
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/integrals/integrals.py:948, in Integral._eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds, final)
#     946 # Piecewise antiderivatives need to call special integrate.
#     947 if isinstance(f, Piecewise):
# --> 948     return f.piecewise_integrate(x, **eval_kwargs)
#     950 # let's cut it short if `f` does not depend on `x`; if
#     951 # x is only a dummy, that will be handled below
#     952 if not f.has(x):
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/functions/elementary/piecewise.py:295, in Piecewise.piecewise_integrate(self, x, **kwargs)
#     261 """Return the Piecewise with each expression being
#     262 replaced with its antiderivative. To obtain a continuous
#     263 antiderivative, use the :func:`~.integrate` function or method.
#    (...)
#     292 Piecewise._eval_integral
#     293 """
#     294 from sympy.integrals import integrate
# --> 295 return self.func(*[(integrate(e, x, **kwargs), c) for e, c in self.args])
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/integrals/integrals.py:1574, in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1571 integral = Integral(*args, **kwargs)
#    1573 if isinstance(integral, Integral):
# -> 1574     return integral.doit(**doit_flags)
#    1575 else:
#    1576     new_args = [a.doit(**doit_flags) if isinstance(a, Integral) else a
#    1577         for a in integral.args]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/integrals/integrals.py:506, in Integral.doit(self, **hints)
#     504 if reps:
#     505     undo = {v: k for k, v in reps.items()}
# --> 506     did = self.xreplace(reps).doit(**hints)
#     507     if isinstance(did, tuple):  # when separate=True
#     508         did = tuple([i.xreplace(undo) for i in did])
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/integrals/integrals.py:619, in Integral.doit(self, **hints)
#     617     antideriv = None
#     618 else:
# --> 619     antideriv = self._eval_integral(
#     620         function, xab[0], **eval_kwargs)
#     621     if antideriv is None and meijerg is True:
#     622         ret = try_meijerg(function, xab)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/integrals/integrals.py:1114, in Integral._eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds, final)
#    1112 if h is None and manual is not False:
#    1113     try:
# -> 1114         result = manualintegrate(g, x)
#    1115         if result is not None and not isinstance(result, Integral):
#    1116             if result.has(Integral) and not manual:
#    1117                 # Try to have other algorithms do the integrals
#    1118                 # manualintegrate can't handle,
#    1119                 # unless we were asked to use manual only.
#    1120                 # Keep the rest of eval_kwargs in case another
#    1121                 # method was set to False already
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/integrals/manualintegrate.py:2164, in manualintegrate(f, var)
#    2115 def manualintegrate(f, var):
#    2116     """manualintegrate(f, var)
#    2117
#    2118     Explanation
#    (...)
#    2162     sympy.integrals.integrals.Integral
#    2163     """
# -> 2164     result = integral_steps(f, var).eval()
#    2165     # Clear the cache of u-parts
#    2166     _parts_u_cache.clear()
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/integrals/manualintegrate.py:2065, in integral_steps(integrand, symbol, **options)
#    2062         return k and issubclass(k, klasses)
#    2063     return _integral_is_subclass
# -> 2065 result = do_one(
#    2066     null_safe(special_function_rule),
#    2067     null_safe(switch(key, {
#    2068         Pow: do_one(null_safe(power_rule), null_safe(inverse_trig_rule),
#    2069                     null_safe(sqrt_linear_rule),
#    2070                     null_safe(quadratic_denom_rule)),
#    2071         Symbol: power_rule,
#    2072         exp: exp_rule,
#    2073         Add: add_rule,
#    2074         Mul: do_one(null_safe(mul_rule), null_safe(trig_product_rule),
#    2075                     null_safe(heaviside_rule), null_safe(quadratic_denom_rule),
#    2076                     null_safe(sqrt_linear_rule),
#    2077                     null_safe(sqrt_quadratic_rule)),
#    2078         Derivative: derivative_rule,
#    2079         TrigonometricFunction: trig_rule,
#    2080         Heaviside: heaviside_rule,
#    2081         DiracDelta: dirac_delta_rule,
#    2082         OrthogonalPolynomial: orthogonal_poly_rule,
#    2083         Number: constant_rule
#    2084     })),
#    2085     do_one(
#    2086         null_safe(trig_rule),
#    2087         null_safe(hyperbolic_rule),
#    2088         null_safe(alternatives(
#    2089             rewrites_rule,
#    2090             substitution_rule,
#    2091             condition(
#    2092                 integral_is_subclass(Mul, Pow),
#    2093                 partial_fractions_rule),
#    2094             condition(
#    2095                 integral_is_subclass(Mul, Pow),
#    2096                 cancel_rule),
#    2097             condition(
#    2098                 integral_is_subclass(Mul, log,
#    2099                 *inverse_trig_functions),
#    2100                 parts_rule),
#    2101             condition(
#    2102                 integral_is_subclass(Mul, Pow),
#    2103                 distribute_expand_rule),
#    2104             trig_powers_products_rule,
#    2105             trig_expand_rule
#    2106         )),
#    2107         null_safe(condition(integral_is_subclass(Mul, Pow), nested_pow_rule)),
#    2108         null_safe(trig_substitution_rule)
#    2109     ),
#    2110     fallback_rule)(integral)
#    2111 del _integral_cache[cachekey]
#    2112 return result
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/strategies/core.py:108, in do_one.<locals>.do_one_rl(expr)
#     106 def do_one_rl(expr: _T) -> _T:
#     107     for rl in rules:
# --> 108         result = rl(expr)
#     109         if result != expr:
#     110             return result
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/strategies/core.py:108, in do_one.<locals>.do_one_rl(expr)
#     106 def do_one_rl(expr: _T) -> _T:
#     107     for rl in rules:
# --> 108         result = rl(expr)
#     109         if result != expr:
#     110             return result
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/strategies/core.py:87, in null_safe.<locals>.null_safe_rl(expr)
#      86 def null_safe_rl(expr: _T) -> _T:
# ---> 87     result = rule(expr)
#      88     if result is None:
#      89         return expr
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/integrals/manualintegrate.py:1837, in trig_substitution_rule(integral)
#    1834     substitutions[sqrt(f(theta)**2)] = f(theta)
#    1835     substitutions[sqrt(f(theta)**(-2))] = 1/f(theta)
# -> 1837 replaced = integrand.subs(symbol, x_func).trigsimp()
#    1838 replaced = manual_subs(replaced, substitutions)
#    1839 if not replaced.has(symbol):
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/core/expr.py:3752, in Expr.trigsimp(self, **args)
#    3750 """See the trigsimp function in sympy.simplify"""
#    3751 from sympy.simplify.trigsimp import trigsimp
# -> 3752 return trigsimp(self, **args)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/simplify/trigsimp.py:565, in trigsimp(expr, inverse, **opts)
#     554     return trigsimp_groebner(new, **opts)
#     556 trigsimpfunc = {
#     557     'fu': (lambda x: fu(x, **opts)),
#     558     'matching': (lambda x: futrig(x)),
#    (...)
#     562     'old': lambda x: trigsimp_old(x, **opts),
#     563                }[method]
# --> 565 expr_simplified = trigsimpfunc(expr)
#     566 if inverse:
#     567     expr_simplified = _trigsimp_inverse(expr_simplified)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/simplify/trigsimp.py:558, in trigsimp.<locals>.<lambda>(x)
#     553         return new
#     554     return trigsimp_groebner(new, **opts)
#     556 trigsimpfunc = {
#     557     'fu': (lambda x: fu(x, **opts)),
# --> 558     'matching': (lambda x: futrig(x)),
#     559     'groebner': (lambda x: groebnersimp(x, **opts)),
#     560     'combined': (lambda x: futrig(groebnersimp(x,
#     561                            polynomial=True, hints=[2, tan]))),
#     562     'old': lambda x: trigsimp_old(x, **opts),
#     563                }[method]
#     565 expr_simplified = trigsimpfunc(expr)
#     566 if inverse:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/simplify/trigsimp.py:1159, in futrig(e, hyper, **kwargs)
#    1156     return e
#    1158 old = e
# -> 1159 e = bottom_up(e, _futrig)
#    1161 if hyper and e.has(HyperbolicFunction):
#    1162     e, f = hyper_as_trig(e)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/core/traversal.py:230, in bottom_up(rv, F, atoms, nonbasic)
#     228 if args is not None:
#     229     if args:
# --> 230         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     231         if args != rv.args:
#     232             rv = rv.func(*args)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/core/traversal.py:230, in bottom_up(rv, F, atoms, nonbasic)
#     228 if args is not None:
#     229     if args:
# --> 230         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     231         if args != rv.args:
#     232             rv = rv.func(*args)
#
#     [... skipping similar frames: bottom_up at line 230 (1 times)]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/core/traversal.py:230, in bottom_up(rv, F, atoms, nonbasic)
#     228 if args is not None:
#     229     if args:
# --> 230         args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#     231         if args != rv.args:
#     232             rv = rv.func(*args)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/core/traversal.py:233, in bottom_up(rv, F, atoms, nonbasic)
#     231     if args != rv.args:
#     232         rv = rv.func(*args)
# --> 233     rv = F(rv)
#     234 elif atoms:
#     235     rv = F(rv)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/simplify/trigsimp.py:1226, in _futrig(e)
#    1187 trigs = lambda x: x.has(TrigonometricFunction)
#    1189 tree = [identity,
#    1190     (
#    1191     TR3,  # canonical angles
#    (...)
#    1224         factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1225     )]
# -> 1226 e = greedy(tree, objective=Lops)(e)
#    1228 if coeff is not None:
#    1229     e = coeff * e
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/strategies/core.py:150, in minimize.<locals>.minrule(expr)
#     149 def minrule(expr: _S) -> _T:
# --> 150     return min([rule(expr) for rule in rules], key=objective)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/strategies/core.py:64, in chain.<locals>.chain_rl(expr)
#      62 def chain_rl(expr: _T) -> _T:
#      63     for rule in rules:
# ---> 64         expr = rule(expr)
#      65     return expr
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/simplify/trigsimp.py:1194, in _futrig.<locals>.<lambda>(x)
#    1186 Lops = lambda x: (L(x), x.count_ops(), _nodes(x), len(x.args), x.is_Add)
#    1187 trigs = lambda x: x.has(TrigonometricFunction)
#    1189 tree = [identity,
#    1190     (
#    1191     TR3,  # canonical angles
#    1192     TR1,  # sec-csc -> cos-sin
#    1193     TR12,  # expand tan of sum
# -> 1194     lambda x: _eapply(factor, x, trigs),
#    1195     TR2,  # tan-cot -> sin-cos
#    1196     [identity, lambda x: _eapply(_mexpand, x, trigs)],
#    1197     TR2i,  # sin-cos ratio -> tan
#    1198     lambda x: _eapply(lambda i: factor(i.normal()), x, trigs),
#    1199     TR14,  # factored identities
#    1200     TR5,  # sin-pow -> cos_pow
#    1201     TR10,  # sin-cos of sums -> sin-cos prod
#    1202     TR11, _TR11, TR6, # reduce double angles and rewrite cos pows
#    1203     lambda x: _eapply(factor, x, trigs),
#    1204     TR14,  # factored powers of identities
#    1205     [identity, lambda x: _eapply(_mexpand, x, trigs)],
#    1206     TR10i,  # sin-cos products > sin-cos of sums
#    1207     TRmorrie,
#    1208     [identity, TR8],  # sin-cos products -> sin-cos of sums
#    1209     [identity, lambda x: TR2i(TR2(x))],  # tan -> sin-cos -> tan
#    1210     [
#    1211         lambda x: _eapply(expand_mul, TR5(x), trigs),
#    1212         lambda x: _eapply(
#    1213             expand_mul, TR15(x), trigs)], # pos/neg powers of sin
#    1214     [
#    1215         lambda x:  _eapply(expand_mul, TR6(x), trigs),
#    1216         lambda x:  _eapply(
#    1217             expand_mul, TR16(x), trigs)], # pos/neg powers of cos
#    1218     TR111,  # tan, sin, cos to neg power -> cot, csc, sec
#    1219     [identity, TR2i],  # sin-cos ratio to tan
#    1220     [identity, lambda x: _eapply(
#    1221         expand_mul, TR22(x), trigs)],  # tan-cot to sec-csc
#    1222     TR1, TR2, TR2i,
#    1223     [identity, lambda x: _eapply(
#    1224         factor_terms, TR12(x), trigs)],  # expand tan of sum
#    1225     )]
#    1226 e = greedy(tree, objective=Lops)(e)
#    1228 if coeff is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/simplify/trigsimp.py:1250, in _eapply(func, e, cond)
#    1248     return e
#    1249 if _is_Expr(e) or not e.args:
# -> 1250     return func(e)
#    1251 return e.func(*[
#    1252     _eapply(func, ei) if (cond is None or cond(ei)) else ei
#    1253     for ei in e.args])
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polytools.py:6577, in factor(f, deep, *gens, **args)
#    6574     return f.xreplace(partials)
#    6576 try:
# -> 6577     return _generic_factor(f, gens, args, method='factor')
#    6578 except PolynomialError:
#    6579     if not f.is_commutative:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polytools.py:6258, in _generic_factor(expr, gens, args, method)
#    6256 opt = options.build_options(gens, args)
#    6257 opt['fraction'] = fraction
# -> 6258 return _symbolic_factor(sympify(expr), opt, method)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polytools.py:6198, in _symbolic_factor(expr, opt, method)
#    6196     if hasattr(expr,'_eval_factor'):
#    6197         return expr._eval_factor()
# -> 6198     coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#    6199     return _keep_coeff(coeff, _factors_product(factors))
#    6200 elif hasattr(expr, 'args'):
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polytools.py:6163, in _symbolic_factor_list(expr, opt, method)
#    6160 else:
#    6161     func = getattr(poly, method + '_list')
# -> 6163     _coeff, _factors = func()
#    6164     if _coeff is not S.One:
#    6165         if exp.is_Integer:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polytools.py:3378, in Poly.factor_list(f)
#    3376 if hasattr(f.rep, 'factor_list'):
#    3377     try:
# -> 3378         coeff, factors = f.rep.factor_list()
#    3379     except DomainError:
#    3380         if f.degree() == 0:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polyclasses.py:1637, in DMP_Python.factor_list(f)
#    1635 def factor_list(f):
#    1636     """Returns a list of irreducible factors of ``f``. """
# -> 1637     coeff, factors = dmp_factor_list(f._rep, f.lev, f.dom)
#    1638     return coeff, [ (f.per(g), k) for g, k in factors ]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/factortools.py:1549, in dmp_factor_list(f, u, K0)
#    1547     coeff, factors = dmp_ext_factor(f, u, K0)
#    1548 elif K0.is_GaussianRing:
# -> 1549     coeff, factors = dmp_zz_i_factor(f, u, K0)
#    1550 elif K0.is_GaussianField:
#    1551     coeff, factors = dmp_qq_i_factor(f, u, K0)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/factortools.py:1249, in dmp_zz_i_factor(f, u, K0)
#    1247 K1 = K0.get_field()
#    1248 f = dmp_convert(f, u, K0, K1)
# -> 1249 coeff, factors = dmp_qq_i_factor(f, u, K1)
#    1251 new_factors = []
#    1252 for fac, i in factors:
#    1253     # Extract content
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/factortools.py:1238, in dmp_qq_i_factor(f, u, K0)
#    1236 K1 = K0.as_AlgebraicField()
#    1237 f = dmp_convert(f, u, K0, K1)
# -> 1238 coeff, factors = dmp_factor_list(f, u, K1)
#    1239 factors = [(dmp_convert(fac, u, K1, K0), i) for fac, i in factors]
#    1240 coeff = K0.convert(coeff, K1)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/factortools.py:1547, in dmp_factor_list(f, u, K0)
#    1545     coeff, factors = dmp_gf_factor(f, u, K0)
#    1546 elif K0.is_Algebraic:
# -> 1547     coeff, factors = dmp_ext_factor(f, u, K0)
#    1548 elif K0.is_GaussianRing:
#    1549     coeff, factors = dmp_zz_i_factor(f, u, K0)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/factortools.py:1420, in dmp_ext_factor(f, u, K)
#    1417 if all(d <= 0 for d in dmp_degree_list(f, u)):
#    1418     return lc, []
# -> 1420 f, F = dmp_sqf_part(f, u, K), f
#    1421 s, g, r = dmp_sqf_norm(f, u, K)
#    1423 factors = dmp_factor_list_include(r, u, K.dom)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/sqfreetools.py:470, in dmp_sqf_part(f, u, K)
#     468 gcd = f
#     469 for i in range(u+1):
# --> 470     gcd = dmp_gcd(gcd, dmp_diff_in(f, 1, i, u, K), u, K)
#     471 sqf = dmp_quo(f, gcd, u, K)
#     473 if K.is_Field:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:1639, in dmp_gcd(f, g, u, K)
#    1622 def dmp_gcd(f, g, u, K):
#    1623     """
#    1624     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1625
#    (...)
#    1637
#    1638     """
# -> 1639     return dmp_inner_gcd(f, g, u, K)[0]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:1598, in dmp_inner_gcd(f, g, u, K)
#    1595     return dup_inner_gcd(f, g, K)
#    1597 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1598 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1600 return (dmp_inflate(h, J, u, K),
#    1601         dmp_inflate(cff, J, u, K),
#    1602         dmp_inflate(cfg, J, u, K))
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:1563, in _dmp_inner_gcd(f, g, u, K)
#    1560         except HeuristicGCDFailed:
#    1561             pass
# -> 1563     return dmp_ff_prs_gcd(f, g, u, K)
#    1564 else:
#    1565     if K.is_ZZ and query('USE_HEU_GCD'):
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:1113, in dmp_ff_prs_gcd(f, g, u, K)
#    1110 if result is not None:
#    1111     return result
# -> 1113 fc, F = dmp_primitive(f, u, K)
#    1114 gc, G = dmp_primitive(g, u, K)
#    1116 h = dmp_subresultants(F, G, u, K)[-1]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:1837, in dmp_primitive(f, u, K)
#    1823 def dmp_primitive(f, u, K):
#    1824     """
#    1825     Returns multivariate content and a primitive polynomial.
#    1826
#    (...)
#    1835
#    1836     """
# -> 1837     cont, v = dmp_content(f, u, K), u - 1
#    1839     if dmp_zero_p(f, u) or dmp_one_p(cont, v, K):
#    1840         return cont, f
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:1812, in dmp_content(f, u, K)
#    1809     return cont
#    1811 for c in f[1:]:
# -> 1812     cont = dmp_gcd(cont, c, v, K)
#    1814     if dmp_one_p(cont, v, K):
#    1815         break
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:1639, in dmp_gcd(f, g, u, K)
#    1622 def dmp_gcd(f, g, u, K):
#    1623     """
#    1624     Computes polynomial GCD of `f` and `g` in `K[X]`.
#    1625
#    (...)
#    1637
#    1638     """
# -> 1639     return dmp_inner_gcd(f, g, u, K)[0]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:1598, in dmp_inner_gcd(f, g, u, K)
#    1595     return dup_inner_gcd(f, g, K)
#    1597 J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1598 h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1600 return (dmp_inflate(h, J, u, K),
#    1601         dmp_inflate(cff, J, u, K),
#    1602         dmp_inflate(cfg, J, u, K))
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:1563, in _dmp_inner_gcd(f, g, u, K)
#    1560         except HeuristicGCDFailed:
#    1561             pass
# -> 1563     return dmp_ff_prs_gcd(f, g, u, K)
#    1564 else:
#    1565     if K.is_ZZ and query('USE_HEU_GCD'):
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:1116, in dmp_ff_prs_gcd(f, g, u, K)
#    1113 fc, F = dmp_primitive(f, u, K)
#    1114 gc, G = dmp_primitive(g, u, K)
# -> 1116 h = dmp_subresultants(F, G, u, K)[-1]
#    1117 c, _, _ = dmp_ff_prs_gcd(fc, gc, u - 1, K)
#    1119 _, h = dmp_primitive(h, u, K)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:549, in dmp_subresultants(f, g, u, K)
#     529 def dmp_subresultants(f, g, u, K):
#     530     """
#     531     Computes subresultant PRS of two polynomials in `K[X]`.
#     532
#    (...)
#     547
#     548     """
# --> 549     return dmp_inner_subresultants(f, g, u, K)[0]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/euclidtools.py:512, in dmp_inner_subresultants(f, g, u, K)
#     507 f, g, m, d = g, h, k, m - k
#     509 b = dmp_mul(dmp_neg(lc, v, K),
#     510             dmp_pow(c, d, v, K), v, K)
# --> 512 h = dmp_prem(f, g, u, K)
#     513 h = [ dmp_quo(ch, b, v, K) for ch in h ]
#     515 lc = dmp_LC(g, K)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/densearith.py:1237, in dmp_prem(f, g, u, K)
#    1234 lc_r = dmp_LC(r, K)
#    1235 j, N = dr - dg, N - 1
# -> 1237 R = dmp_mul_term(r, lc_g, 0, u, K)
#    1238 G = dmp_mul_term(g, lc_r, j, u, K)
#    1239 r = dmp_sub(R, G, u, K)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/densearith.py:184, in dmp_mul_term(f, c, i, u, K)
#     182     return dmp_zero(u)
#     183 else:
# --> 184     return [ dmp_mul(cf, c, v, K) for cf in f ] + dmp_zeros(i, v, K)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
#     [... skipping similar frames: dmp_mul at line 828 (4 times)]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/densearith.py:828, in dmp_mul(f, g, u, K)
#     825     coeff = dmp_zero(v)
#     827     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 828         coeff = dmp_add(coeff, dmp_mul(f[j], g[i - j], v, K), v, K)
#     830     h.append(coeff)
#     832 return dmp_strip(h, u)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/densearith.py:807, in dmp_mul(f, g, u, K)
#     793 """
#     794 Multiply dense polynomials in ``K[X]``.
#     795
#    (...)
#     804
#     805 """
#     806 if not u:
# --> 807     return dup_mul(f, g, K)
#     809 if f == g:
#     810     return dmp_sqr(f, u, K)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/densearith.py:767, in dup_mul(f, g, K)
#     764     coeff = K.zero
#     766     for j in range(max(0, i - dg), min(df, i) + 1):
# --> 767         coeff += f[j]*g[i - j]
#     769     h.append(coeff)
#     771 return dup_strip(h)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polyclasses.py:3039, in ANP.__add__(f, g)
#    3037 def __add__(f, g):
#    3038     if isinstance(g, ANP):
# -> 3039         return f.add(g)
#    3040     try:
#    3041         g = f.dom.convert(g)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polyclasses.py:2965, in ANP.add(f, g)
#    2963 def add(f, g):
#    2964     F, G, mod, dom = f.unify_ANP(g)
# -> 2965     return f.new(F.add(G), mod, dom)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polyclasses.py:499, in DMP.add(f, g)
#     497 """Add two multivariate polynomials ``f`` and ``g``. """
#     498 F, G = f.unify_DMP(g)
# --> 499 return F._add(G)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polyclasses.py:1379, in DMP_Python._add(f, g)
#    1377 def _add(f, g):
#    1378     """Add two multivariate polynomials ``f`` and ``g``. """
# -> 1379     return f.per(dmp_add(f._rep, g._rep, f.lev, f.dom))
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polyclasses.py:1253, in DMP_Python.per(f, rep)
#    1251 def per(f, rep):
#    1252     """Create a DMP out of the given representation. """
# -> 1253     return f._new(rep, f.dom, f.lev)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/sympy/polys/polyclasses.py:1240, in DMP_Python._new(cls, rep, dom, lev)
#    1238 @classmethod
#    1239 def _new(cls, rep, dom, lev):
# -> 1240     obj = object.__new__(cls)
#    1241     obj._rep = rep
#    1242     obj.lev = lev
#
# KeyboardInterrupt:

# %%
from scipy import LowLevelCallable, integrate
import ctypes
import numpy as np
# Define the integrands as a Python functions - this is slow

# integrand1 = lambda x,y,z: np.sqrt(x**2 + y**2 -z**2)
# integrand2 = lambda x,y,z: np.sqrt((1-x)**2 + y**2 -z**2)

# Define C functions and call those instead

# run this to generate .so file from integrand.c
# gcc -shared -fPIC -o integrand.so integrand.c

lib = ctypes.CDLL("integrand.so")
lib.integrand1.restype = ctypes.c_double
lib.integrand2.restype = ctypes.c_double

lib.integrand1.argtypes = (ctypes.c_int, ctypes.POINTER(ctypes.c_double))
lib.integrand2.argtypes = (ctypes.c_int, ctypes.POINTER(ctypes.c_double))

integrand1 = LowLevelCallable(lib.integrand1)
integrand2 = LowLevelCallable(lib.integrand2)

xbounds = lambda: [0, 0.5]
ybounds = lambda x: [0, x]
zbounds1 = lambda x,y: [0, x]
zbounds2 = lambda x,y: [0, 1-x]

integral1, err1 = integrate.nquad(integrand1, [zbounds1, ybounds, xbounds])
integral2, err2 = integrate.nquad(integrand2, [zbounds2, ybounds, xbounds])

res = 8 * (integral1 + integral2)
err = err1 + err2
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1272: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,

# %%
# after some more analysis, let's use analytic solutions for the first integrals of integrand1 and integrand2
# area of the shaded circle area is:

# shaded = lambda x,y : 0.25 * (x**2 + y**2) * (np.pi - 2*np.atan2(y,x) + np.sin(2*np.atan2(y,x)))

def shaded(x, y):
    theta = 2*np.arctan2(y,x)
    r2 = x**2 + y**2
    return 0.5 * r2 * (0.5*np.pi + np.sin(theta) - theta)
    

res, err = integrate.dblquad(shaded, 0, 0.5, lambda x: 0, lambda x: x)
res, err
# Out:
# (0.0015981917679169517, 6.04844472721988e-16)

# %%
res, err = integrate.dblquad(lambda x,y: shaded(1-x, y), 0, 0.5, lambda x: 0, lambda x: x)
res, err

# %%
np.arctan2(1/np.sqrt(2),1/np.sqrt(2))/np.pi
# Out:
# 0.25
